# %% [markdown]
# # Visualization

# %% [markdown]
# ![elgif](https://media.giphy.com/media/3og0IExSrnfW2kUaaI/giphy.gif)

# %% [markdown]
# # Motivación
#
# En el ámbito de Python, poseemos un conjunto de herramientas potentes que nos permiten crear una amplia variedad de visualizaciones. En esta clase, profundizaremos en estas herramientas, centrándonos principalmente en el uso de Matplotlib, Pylab y Seaborn. Nuestro objetivo principal es aprovechar el poder de las visualizaciones para realizar Análisis Exploratorio de Datos (AED).
#
# **Por qué la Visualización es Importante**
#
# La visualización actúa como un pilar fundamental en el ámbito del análisis de datos. Nos permite no solo ver los datos, sino también descubrir patrones complejos, insights ocultos y tendencias críticas. A través de la visualización, podemos describir y comunicar eficazmente la esencia de los datos, haciéndola una herramienta indispensable en el campo del AED.
#
# **Matplotlib, Pylab y Seaborn**
#
# En nuestro viaje, exploraremos tres librerias clave: Matplotlib, Pylab y Seaborn. Estas bibliotecas nos proporcionan una amplia gama de herramientas, funciones y opciones para crear visualizaciones diversas e impactantes. Ya sea que busques realizar simples gráficas de líneas o complejos mapas de calor, estas bibliotecas te tienen cubierto.
#
# Nuestra exploración abarcará una gama de técnicas de visualización, incluyendo gráficos de dispersión, gráficas de barras, histogramas y más. Aprenderemos cómo personalizar y anotar nuestras visualizaciones para transmitir información precisa de manera efectiva.
#
# A través de este curso, ganarás las habilidades necesarias para extraer valiosos insights de los datos, contar historias convincentes impulsadas por datos y tomar decisiones informadas, todo con el poder de la visualización.
#
# Así que, ¡sumérgete en el mundo de la visualización de datos con Matplotlib, Pylab y Seaborn y libera el potencial de tus datos!

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#COMPARISON" data-toc-modified-id="COMPARISON-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>COMPARISON</a></span><ul class="toc-item"><li><span><a href="#Bar-chart" data-toc-modified-id="Bar-chart-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Bar chart</a></span><ul class="toc-item"><li><span><a href="#seaborn:-countplot" data-toc-modified-id="seaborn:-countplot-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>seaborn: countplot</a></span></li><li><span><a href="#seaborn:-barplot" data-toc-modified-id="seaborn:-barplot-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>seaborn: barplot</a></span></li><li><span><a href="#matplotlib:-barplot" data-toc-modified-id="matplotlib:-barplot-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>matplotlib: barplot</a></span></li></ul></li><li><span><a href="#Column:-grouped-bar-chart" data-toc-modified-id="Column:-grouped-bar-chart-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Column: grouped bar chart</a></span><ul class="toc-item"><li><span><a href="#seaborn:-countplot" data-toc-modified-id="seaborn:-countplot-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>seaborn: countplot</a></span></li></ul></li><li><span><a href="#matplotlib:-bar-chart" data-toc-modified-id="matplotlib:-bar-chart-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>matplotlib: bar chart</a></span></li><li><span><a href="#Line-chart" data-toc-modified-id="Line-chart-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Line chart</a></span></li><li><span><a href="#Scatter-plot" data-toc-modified-id="Scatter-plot-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Scatter plot</a></span><ul class="toc-item"><li><span><a href="#seaborn:-scatterplot" data-toc-modified-id="seaborn:-scatterplot-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>seaborn: scatterplot</a></span></li><li><span><a href="#matplotlib:-scatterplot" data-toc-modified-id="matplotlib:-scatterplot-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>matplotlib: scatterplot</a></span></li></ul></li></ul></li><li><span><a href="#DISTRIBUTION" data-toc-modified-id="DISTRIBUTION-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>DISTRIBUTION</a></span><ul class="toc-item"><li><span><a href="#Histograms" data-toc-modified-id="Histograms-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Histograms</a></span></li></ul></li><li><span><a href="#SMALL-RECAP" data-toc-modified-id="SMALL-RECAP-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>SMALL RECAP</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#seaborn:-histograms" data-toc-modified-id="seaborn:-histograms-3.0.1"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>seaborn: histograms</a></span></li><li><span><a href="#matplotlib:-histograms" data-toc-modified-id="matplotlib:-histograms-3.0.2"><span class="toc-item-num">3.0.2&nbsp;&nbsp;</span>matplotlib: histograms</a></span></li></ul></li><li><span><a href="#With-categorical-variables" data-toc-modified-id="With-categorical-variables-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>With categorical variables</a></span></li><li><span><a href="#swarmplot" data-toc-modified-id="swarmplot-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>swarmplot</a></span></li><li><span><a href="#Boxplot" data-toc-modified-id="Boxplot-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Boxplot</a></span></li><li><span><a href="#ViolinPlot" data-toc-modified-id="ViolinPlot-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>ViolinPlot</a></span></li><li><span><a href="#KDE-plot" data-toc-modified-id="KDE-plot-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>KDE plot</a></span><ul class="toc-item"><li><span><a href="#With-more-variables" data-toc-modified-id="With-more-variables-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>With more variables</a></span></li><li><span><a href="#Add-KDE-to-the-histplot" data-toc-modified-id="Add-KDE-to-the-histplot-3.5.2"><span class="toc-item-num">3.5.2&nbsp;&nbsp;</span>Add KDE to the histplot</a></span></li></ul></li></ul></li><li><span><a href="#PART-OF-A-WHOLE" data-toc-modified-id="PART-OF-A-WHOLE-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>PART OF A WHOLE</a></span><ul class="toc-item"><li><span><a href="#Pie-plot-👀" data-toc-modified-id="Pie-plot-👀-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Pie plot 👀</a></span></li><li><span><a href="#Stacked-column-chart" data-toc-modified-id="Stacked-column-chart-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Stacked column chart</a></span><ul class="toc-item"><li><span><a href="#seaborn:-stacked-column-(histogram)" data-toc-modified-id="seaborn:-stacked-column-(histogram)-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>seaborn: stacked column (histogram)</a></span></li></ul></li></ul></li><li><span><a href="#RELATIONSHIPS" data-toc-modified-id="RELATIONSHIPS-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>RELATIONSHIPS</a></span><ul class="toc-item"><li><span><a href="#Scatter-plot" data-toc-modified-id="Scatter-plot-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Scatter plot</a></span></li><li><span><a href="#Line-chart" data-toc-modified-id="Line-chart-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Line chart</a></span></li><li><span><a href="#Correlation-Matrix" data-toc-modified-id="Correlation-Matrix-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Correlation Matrix</a></span></li><li><span><a href="#Pairplot" data-toc-modified-id="Pairplot-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Pairplot</a></span></li></ul></li><li><span><a href="#TRENDS" data-toc-modified-id="TRENDS-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>TRENDS</a></span><ul class="toc-item"><li><span><a href="#Line-chart" data-toc-modified-id="Line-chart-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Line chart</a></span></li><li><span><a href="#Area-chart" data-toc-modified-id="Area-chart-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Area chart</a></span></li><li><span><a href="#Column-chart:-grouped-bar-chart" data-toc-modified-id="Column-chart:-grouped-bar-chart-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Column chart: grouped bar chart</a></span></li><li><span><a href="#Jointplot:-histograms-&amp;-scatterplot" data-toc-modified-id="Jointplot:-histograms-&amp;-scatterplot-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Jointplot: histograms &amp; scatterplot</a></span></li></ul></li><li><span><a href="#Subplots" data-toc-modified-id="Subplots-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Subplots</a></span></li><li><span><a href="#Save-Plots" data-toc-modified-id="Save-Plots-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Save Plots</a></span></li></ul></div>

# %% [markdown]
# # Importamos librerias

# %%
# Importing the Seaborn library for advanced data visualization (as sns)
import seaborn as sns

# Importing the Matplotlib library for basic plotting functionalities (as plt)
import matplotlib.pyplot as plt

# Importing the Pandas library for data manipulation and analysis (as pd)
import pandas as pd

# Importing the NumPy library for numerical operations (as np)
import numpy as np

# %% [markdown]
# # Cargamos datos

# %%
# Importing Pandas library and reading the Titanic dataset from a CSV file
titanic = pd.read_csv('./datasets/titanic.csv')
#titanic2=sns.load_dataset("titanic")

# Importing Seaborn library and loading the 'penguins' dataset
penguins = sns.load_dataset("penguins")

# Importing Seaborn library and loading the 'tips' dataset
tips = sns.load_dataset("tips")

# Importing Seaborn library and loading the 'flights' dataset
flights = sns.load_dataset("flights")

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
# Are we missing some extra steps to understands the dataframes?

# %% [markdown]
# # Ajustes de Visualización

# %%
# Matplotlib inline to visualize Matplotlib graphs
# %matplotlib inline

# Configuration to set so that all the Seaborn figures come out with this size
# %config Inlinebackend.figure_format= 'retina'

# %%
# Set the Seaborn context to "poster" for larger text and figures
sns.set_context("poster")

# Set the default figure size for Seaborn plots
sns.set(rc={"figure.figsize": (12., 6.)})

# Set the Seaborn style to "whitegrid" for a white background with gridlines
sns.set_style("whitegrid")

# %% [markdown]
# - **COMPARACIÓN**
#     - **Gráfico de Barras:** Utilizado para comparar puntos de datos individuales a través de categorías. Cada barra representa una categoría y la altura o longitud de la barra es proporcional al valor o conteo de esa categoría.
#     - **Gráfico de Barras Agrupadas:** Una variación del gráfico de barras que muestra dos o más grupos lado a lado para la comparación a través de categorías y subcategorías.
#     - **Gráfico de Líneas:** Ideal para mostrar tendencias a lo largo del tiempo. Cada punto en la línea representa un valor de datos en un período de tiempo específico.
#     - **Diagrama de Dispersión:** Perfecto para mostrar la relación entre dos variables numéricas, permitiendo la identificación de correlaciones, patrones o valores atípicos.
#
# - **DISTRIBUCIÓN**
#     - **Histograma:** Proporciona una visualización de la distribución de frecuencias subyacente de un conjunto de datos numéricos continuos o discretos.
#     - **Swarmplot:** Representa todos los puntos de datos a lo largo de un eje, útil para mostrar la distribución de un conjunto de datos e identificar posibles valores atípicos.
#     - **Diagrama de Caja:** Resume la distribución de un conjunto de datos basado en el resumen de cinco números: mínimo, primer cuartil (Q1), mediana, tercer cuartil (Q3) y máximo.
#     - **Diagrama de Violín:** Combina las propiedades de los diagramas de caja y los gráficos de densidad kernel, proporcionando un resumen de la distribución de los datos.
#
# - **PARTE DE UN TODO**
#     - **Gráfico Circular:** Representa proporciones o porcentajes entre categorías, dividiendo un círculo en segmentos proporcionales.
#     - **Gráfico de Columnas Apiladas:** Muestra la comparación de los totales individuales de subcategorías con el total general.
#
# - **RELACIONES**
#     - **Diagrama de Dispersión:** Ideal para representar la relación entre dos variables numéricas, permitiendo la detección de correlaciones, patrones o valores atípicos.
#     - **Gráfico de Líneas:** Útil para mostrar tendencias a lo largo del tiempo, mostrando la relación entre dos variables numéricas a lo largo de un lapso de tiempo continuo.
#     - **Mapa de Calor:** Proporciona una representación gráfica coloreada de datos donde los valores individuales se representan como colores, útil para representar correlaciones o magnitudes.
#     - **Pairplot:** Muestra relaciones por pares en un conjunto de datos, ideal para visualizar rápidamente distribuciones y correlaciones.
#
# - **TENDENCIAS**
#     - **Gráfico de Líneas:** Efectivo para representar tendencias a lo largo de un intervalo de tiempo continuo o discreto.
#     - **Gráfico de Área:** Similar a los gráficos de líneas pero con el área bajo la línea rellenada, útil para representar el efecto acumulativo o total a lo largo del tiempo.
#     - **Gráfico de Columnas:** Útil para comparar categorías discretas de datos, mostrando las diferencias entre ellas a través de barras verticales.

# %% [markdown]
# ## COMPARACIÓN

# %% [markdown]
# - **Gráfico de Barras:** Un gráfico simple que representa los datos con barras rectangulares de diferentes alturas.
#
# - **Gráfico de Barras Agrupadas:** Un gráfico que muestra varias barras una al lado de la otra, permitiendo la comparación entre grupos.
#
# - **Gráfico de Líneas:** Un gráfico que muestra puntos de datos conectados por líneas, útil para visualizar tendencias a lo largo del tiempo.
#
# - **Diagrama de Dispersión:** Un gráfico que representa puntos de datos individuales en un plano bidimensional, útil para mostrar relaciones entre variables.
#
# ### Gráfico de Barras
#
# #### seaborn: countplot
# Un countplot es una visualización fundamental que nos permite crear un gráfico de barras básico para contar el número de ocurrencias de cada categoría dentro de una variable categórica. En este contexto específico, estamos utilizando la biblioteca Seaborn para crear un countplot para analizar la distribución de especies de pingüinos.
#
# **Descripción (trabajará con el pingüino):**
# - El countplot se utiliza para visualizar y comparar la frecuencia o conteo de cada especie única de pingüino en el conjunto de datos.
# - Proporciona una forma rápida y sencilla de entender la distribución de especies dentro de la población de pingüinos.

# %% [markdown]
# `penguin by species❓`

# %%
# Display a random sample of 5 rows from the 'penguins' DataFrame
penguins.sample(5)
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 47      Adelie   Dream            37.5           18.9              179.0
# 43      Adelie   Dream            44.1           19.7              196.0
# 161  Chinstrap   Dream            51.3           19.9              198.0
# 302     Gentoo  Biscoe            47.4           14.6              212.0
# 233     Gentoo  Biscoe            48.4           14.6              213.0
#
#      body_mass_g     sex
# 47        2975.0     NaN
# 43        4400.0    Male
# 161       3700.0    Male
# 302       4725.0  Female
# 233       5850.0    Male

# %%
# Group the 'penguins' DataFrame by the 'species' column and count the occurrences of each species
# The result will show the count of penguins for each species in the dataset
penguins.groupby("species").agg("count")
# Out:
#            island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# species
# Adelie        152             151            151                151
# Chinstrap      68              68             68                 68
# Gentoo        124             123            123                123
#
#            body_mass_g  sex
# species
# Adelie             151  146
# Chinstrap           68   68
# Gentoo             123  119

# %%
# Create a countplot using Seaborn to visualize the distribution of penguin species
# The 'x' parameter specifies the 'species' column to plot on the x-axis
sns.countplot(x=penguins.species);

# %% [markdown]
# Podemos cambiar los colores de los gráficos usando el argumento `palette = "código de color"`
# Consulta las paletas de seaborn --> [Aquí](https://seaborn.pydata.org/tutorial/color_palettes.html)

# %%
# Create a countplot using Seaborn to visualize the distribution of penguin species
# The 'x' parameter specifies the 'species' column to plot on the x-axis
# The 'palette' parameter specifies the color palette to use for the plot (in this case, "magma" colormap)
sns.countplot(x=penguins["species"], palette="magma");
# Out:
# C:\Users\TONAC\AppData\Local\Temp\ipykernel_6748\2299182733.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=penguins["species"], palette="magma");

# %% [markdown]
# Podemos nombrar los nombres de variables en `data` o datos vectoriales:

# %%
# Create a countplot using Seaborn to visualize the distribution of penguin species
# The 'data' parameter specifies the DataFrame 'penguins' containing the data
# The 'x' parameter specifies the 'species' column to plot on the x-axis
# The 'palette' parameter specifies the color palette to use for the plot (in this case, "magma" colormap)
sns.countplot(data=penguins, x="species", palette="magma");
# Out:
# C:\Users\TONAC\AppData\Local\Temp\ipykernel_6748\1805856851.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=penguins, x="species", palette="magma");

# %% [markdown]
# #### seaborn: barplot

# %% [markdown]
# El barplot de Seaborn es una visualización versátil que nos permite representar la tendencia central de una variable numérica usando barras rectangulares. A diferencia del countplot, que se utiliza para datos categóricos, el barplot está diseñado para datos numéricos. Proporciona una representación visual del valor medio estimado para cada categoría dentro de una variable categórica, junto con una medida de incertidumbre representada por barras de error.
#
# **Descripción:**
# - El barplot es particularmente útil cuando quieres comparar los valores medios de una variable numérica a través de diferentes categorías.
# - Cada barra rectangular en el gráfico representa una categoría, y la altura de la barra corresponde a la tendencia central estimada (típicamente la media) de la variable numérica para esa categoría.
# - Se incluyen barras de error para indicar la incertidumbre o variabilidad alrededor del valor estimado. Estas barras de error pueden personalizarse para representar varias medidas estadísticas.

# %% [markdown]
# `average passengers by year❓`

# %%
# Display the first few rows of the 'flights' DataFrame
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
# Grouping the data by 'year' and calculating the mean of 'passengers' rounded to 3 decimal places
flights.groupby("year")["passengers"].mean().round(3)
# Out:
# year
# 1949    126.667
# 1950    139.667
# 1951    170.167
# 1952    197.000
# 1953    225.000
# 1954    238.917
# 1955    284.000
# 1956    328.250
# 1957    368.417
# 1958    381.000
# 1959    428.333
# 1960    476.167
# Name: passengers, dtype: float64

# %%
# Creating a barplot to visualize the average number of passengers by year
# The 'ci=None' parameter is used to exclude confidence intervals
barplot = sns.barplot(x="year", y="passengers", data=flights, ci=None)
# Out:
# C:\Users\TONAC\AppData\Local\Temp\ipykernel_6748\3173569008.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   barplot = sns.barplot(x="year", y="passengers", data=flights, ci=None)

# %% [markdown]
# `total passengers by year❓`

# %%
# Creating a barplot to visualize the total number of passengers by year
# 'x' represents the 'year' data, and 'y' represents the 'passengers' data
# 'palette="magma"' sets the color palette to 'magma'
# 'estimator=sum' calculates the sum of passengers for each year
# 'ci=None' is used to exclude confidence intervals
sns.barplot(x=flights["year"], y=flights["passengers"], palette="magma", estimator=sum, ci=None);
# Out:
# C:\Users\TONAC\AppData\Local\Temp\ipykernel_6748\60996211.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=flights["year"], y=flights["passengers"], palette="magma", estimator=sum, ci=None);
# C:\Users\TONAC\AppData\Local\Temp\ipykernel_6748\60996211.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=flights["year"], y=flights["passengers"], palette="magma", estimator=sum, ci=None);

# %% [markdown]
# El `barplot` de Seaborn es una herramienta versátil para crear gráficos de barras para visualizar datos. Ofrece una forma simplificada y visualmente atractiva de representar tus datos, facilitando la comunicación de información de manera efectiva. Puedes explorar más sobre su funcionalidad en la [documentación oficial de Seaborn](https://seaborn.pydata.org/generated/seaborn.barplot.html).
#
# **¿Cuándo Usar Matplotlib o Seaborn?**
#
# Tanto Matplotlib como Seaborn son bibliotecas potentes para crear visualizaciones en Python. Sin embargo, elegir una sobre la otra depende de tus necesidades y preferencias específicas.
#
# - **Matplotlib**: Es una biblioteca altamente personalizable y flexible, que te permite crear visualizaciones complejas desde cero. Si requieres control total sobre cada aspecto de tu gráfico o necesitas crear tipos de gráficos no convencionales, Matplotlib puede ser la mejor opción.
#
# - **Seaborn**: Seaborn se construye sobre Matplotlib y proporciona una sintaxis de más alto nivel y más concisa para crear visualizaciones estéticamente agradables y de aspecto moderno. Es particularmente útil para gráficos estadísticos comunes y puede ahorrarte tiempo al crear gráficos estándar.
#
# En resumen, Seaborn es una excelente opción cuando quieres crear rápidamente visualizaciones elegantes con menos código. Sin embargo, si necesitas control total o tienes requisitos de personalización específicos, Matplotlib sigue siendo una opción poderosa. La elección entre ambos finalmente depende de los objetivos de tu proyecto y tus preferencias personales.

# %% [markdown]
# #### matplotlib: barplot
# En Matplotlib, el equivalente del countplot que creamos usando Seaborn se conoce como "bar plot" (gráfico de barras). Esencialmente, es un gráfico de barras que representa los mismos datos.
#
# Para crear un gráfico de barras en Matplotlib, necesitas agrupar tu DataFrame según sea necesario y luego usar el método `.plot` para generar el gráfico.

# %% [markdown]
# `penguins by species❓`

# %%
# Count the number of penguins in each species and display the counts
species_counts = penguins["species"].value_counts()

# %%
# Create a bar plot to visualize the penguin species counts
species_counts.plot(kind="bar", title="Number of penguins by species")

# Rotate the x-axis labels slightly for better readability
# By default, the x-axis labels (species names) may be horizontal and could overlap if too long.
# 'plt.xticks(rotation=0)' is used to customize the appearance of the x-axis labels.
# In this case, 'rotation=0' means that we want to keep the labels horizontal (no rotation).
# Depending on the length of the labels or personal preference, you can adjust the rotation angle.
# Rotating labels can help prevent overlap and make the plot more readable.
plt.xticks(rotation=0)

# Customize the y-axis label
plt.ylabel("Number of Penguins")
# Out:
# Text(0, 0.5, 'Number of Penguins')

# %%
# Count the number of penguins in each species and display the counts
species_counts = penguins["species"].value_counts()

# Create a bar plot with specific options:
# - 'kind="bar"' specifies the type of plot as a bar chart
# - 'color="salmon"' sets the color of the bars to salmon
# - 'title="Number of penguins by species"' adds a title to the plot
species_counts.plot(kind="bar", color="salmon", title="Number of penguins by species")

# Rotate the x-axis labels slightly for better readability
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, 'Adelie'), Text(1, 0, 'Gentoo'), Text(2, 0, 'Chinstrap')])

# %% [markdown]
# ### Column: grouped bar chart

# %% [markdown]
# En la visualización de datos, un gráfico de barras agrupadas nos permite presentar datos con un nivel adicional de detalle y complejidad. Logramos esto utilizando el parámetro `hue`, una herramienta poderosa proporcionada por seaborn. Cuando usamos el parámetro `hue` en un gráfico de barras agrupadas, efectivamente multiplica el número de barras por los valores distintos de una variable específica que especificamos.
#
# En este ejemplo, estamos trabajando con el conjunto de datos del Titanic de seaborn. Al incorporar el parámetro `hue`, podemos segmentar y diferenciar las barras dentro de cada categoría, proporcionando información sobre múltiples dimensiones de nuestros datos. Este enfoque es particularmente útil cuando queremos visualizar relaciones y comparaciones entre diferentes subgrupos o variables categóricas, haciendo que nuestros gráficos sean más informativos e intuitivos.

# %% [markdown]
# `how many people survived/didn't survive by class❓`

# %%
# we can add plt. things from matplotlib into seaborn
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Create a countplot to visualize the number of people surviving per class
# We use the 'Pclass' column for the x-axis (representing the passenger class)
# and the 'Survived' column for the hue (coloring bars based on survival status)
# We also specify a color palette using 'palette' for visual appeal
sns.countplot(x=titanic["Pclass"], hue=titanic["Survived"], palette="magma")

# Add a legend to the plot to label the 'dead' and 'not dead :)' categories
plt.legend(labels=['dead', 'not dead :)'])

# %%
# Create a countplot to visualize the number of people surviving per class
# We use the 'Pclass' column for the x-axis (representing the passenger class)
# and the 'Survived' column for the hue (coloring bars based on survival status)
# We also specify a color palette using 'palette' for visual appeal
sns.countplot(x=titanic["Pclass"], hue=titanic["Survived"], palette="magma")

# Add a legend to the plot to label the 'dead' and 'not dead :)' categories
plt.legend(labels=['dead', 'not dead :)'])

# %% [markdown]
# `how many penguins are male/female by species❓`

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# #### seaborn: countplot

# %%
# Create a countplot to visualize the count of penguins' species by sex
# We use the 'species' column for the x-axis (representing penguin species)
# and the 'sex' column for the hue (coloring bars based on gender)
sns.countplot(x="species", hue="sex", data=penguins)
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
# Create a countplot to visualize the count of penguins' species by sex
# We use the 'species' column for the x-axis (horizontal bars representing penguin species)
# and the 'sex' column for the hue (coloring bars based on gender)
sns.countplot(x=penguins.species, hue=penguins.sex)
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %% [markdown]
# El mismo gráfico pero horizontal 🙃

# %%
# Create a countplot to visualize the count of penguins' species by sex
# We use the 'species' column for the y-axis (vertical bars representing penguin species)
# and the 'sex' column for the hue (coloring bars based on gender)
sns.countplot(y=penguins.species, hue=penguins.sex)
# Out:
# <Axes: xlabel='count', ylabel='species'>

# %% [markdown]
# `¿cuántas personas son hombres/mujeres por clase❓`

# %% [markdown]
# Agregamos otra variable que tiene más categorías, en seaborn las barras se colorean por sí mismas 🌈

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Create a countplot to visualize the count of passengers' gender by passenger class (Pclass)
# The 'Sex' column is used for the x-axis (horizontal bars representing gender)
# The 'Pclass' column is used for the hue (coloring bars based on passenger class)
# The order of the 'x' and 'hue' arguments doesn't matter when using variable names
sns.countplot(hue="Pclass", data=titanic, x="Sex")
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %% [markdown]
# ### matplotlib: gráfico de barras
#
# En matplotlib, un gráfico de barras es similar al countplot que hemos visto en seaborn. Es una representación gráfica que utiliza barras para mostrar datos. Para crear un gráfico de barras en matplotlib, típicamente comienzas con un DataFrame que ha sido agrupado según sea necesario, y luego agregas el método `.plot` para generar el gráfico.
#
# Los gráficos de barras en matplotlib pueden personalizarse extensamente, permitiéndote controlar varios aspectos de la apariencia del gráfico, como colores, etiquetas y anotaciones. Mientras que seaborn proporciona una forma más simplificada y visualmente atractiva de crear gráficos de barras, matplotlib ofrece una mayor flexibilidad para ajustes finos y personalización.
#
# Vamos a explorar cómo crear un gráfico de barras básico usando matplotlib para visualizar datos de diferentes maneras.
#
# `¿cuántos pingüinos son macho/hembra por especie❓`
#
# Vamos a intentar, en partes, obtener el mismo gráfico que tenemos arriba, en el cual contamos los pingüinos por especie y sexo.
#
# Primero tenemos que agrupar los datos:

# %%
# Let's rememebr the dataframe
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
# Grouping the penguins DataFrame by both 'species' and 'sex' columns
# Then, counting the occurrences of 'sex' within each group and creating a bar chart
penguins.groupby(["species", "sex"])["sex"].count().plot(kind="bar")

# Adding a title to the bar chart
plt.title('Number of Penguins by Species and Sex')

# Labeling the x-axis
plt.xlabel('Species and Sex')

# Labeling the y-axis
plt.ylabel('Count')

# Displaying the bar chart
plt.show()

# %% [markdown]
# **Personalizando los Colores de los Gráficos de Barras en Matplotlib**
#
# En la visualización de datos, personalizar los colores de tus gráficos y tramas es una manera poderosa de mejorar su atractivo visual y transmitir información de manera efectiva. Matplotlib, una biblioteca de Python ampliamente utilizada para crear visualizaciones estáticas, animadas e interactivas, ofrece varias opciones para personalizar los colores en tus gráficos.
#
# Para personalizar los colores de las barras en un gráfico de barras usando Matplotlib, puedes usar el parámetro `color`. Este parámetro te permite especificar los colores de las barras individuales en el gráfico, proporcionando flexibilidad para lograr el esquema de color deseado.
#
# Aquí te mostramos cómo puedes personalizar los colores de un gráfico de barras en Matplotlib:
#
# 1. Importa las bibliotecas requeridas, típicamente `matplotlib.pyplot` para la creación de gráficos.
# 2. Crea tu conjunto de datos, definiendo las categorías y los valores correspondientes.
# 3. Crea un gráfico de barras básico usando `plt.bar()`.
# 4. Agrega el parámetro `color` a tu función `plt.bar()` y especifica los colores que deseas usar. Puedes usar colores nombrados o proporcionar valores RGB.
#
# Puedes experimentar con diferentes colores y combinaciones para crear gráficos de barras visualmente atractivos e informativos. Para una lista completa de colores nombrados disponibles en Matplotlib, puedes referirte a la [lista de colores nombrados en Matplotlib](https://matplotlib.org/stable/gallery/color/named_colors.html).

# %%
# Group the penguins dataframe by two variables: "species" and "sex," and then count the occurrences of each combination.
# This gives us a count of penguins for each species and gender.
penguin_counts = penguins.groupby(["species", "sex"])["sex"].count()

# Create a bar chart to visualize the penguin counts.
# Use the "kind" parameter to specify that we want a bar chart.
# Additionally, set the colors for the bars using the "color" parameter.
# The first color "slategray" corresponds to one gender, and the second color "coral" corresponds to the other gender.
penguin_counts.plot(kind="bar", color=["slategray", "coral"])

# Add axis labels, titles, and legends if necessary for clarity.
plt.xlabel("Species and Gender", fontsize=15)
plt.ylabel("Count", fontsize=15)
plt.title("Penguin Counts by Species and Gender", fontsize=20)

# Show the plot.
plt.show()

# %% [markdown]
# Para hacer que las barras se agrupen en un gráfico de barras agrupadas, necesitamos realizar una operación llamada `unstack()` en el DataFrame. Esto es particularmente útil cuando se trabaja con datos de multi-índice, que es una disposición jerárquica de índices.
#
# **Stacking y unstacking** son operaciones en Pandas que te permiten remodelar tus datos entre formatos largos (stacked) y anchos (unstacked):
#
# - **Stacking** típicamente implica mover datos de columnas a filas, creando un índice jerárquico (de múltiples niveles). Es útil para hacer que tus datos sean largos y estrechos.
#
# - **Unstacking** hace lo contrario, moviendo datos de filas de vuelta a columnas, esencialmente pivotando tus datos. Esto es útil para crear datos en formato ancho, que a menudo se utilizan en visualizaciones como gráficos de barras agrupadas.
#
# Entonces, para agrupar barras en un gráfico de barras, desapilaremos nuestro DataFrame, lo que reorganizará los datos en un formato que es adecuado para crear barras agrupadas. Puedes aprender más sobre el método `unstack()` [aquí](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.unstack.html).
#
# Para una comprensión más profunda del multi-índice en Pandas, puedes referirte a la documentación oficial sobre [indexación avanzada](https://pandas.pydata.org/pandas-docs/stable/user_guide/advanced.html).
#
# ![stack y unstack](https://miro.medium.com/max/1400/1*DYDOif_qBEgtWfFKUDSf0Q.png)

# %%
# Do you remember the function I provided to ensure uniformity in the datafrmes? Sometimes is not required, 
# and the output is good for us
hola2 = pd.DataFrame(penguins.groupby(["species", "sex"])["sex"].count()).unstack()
hola2.head()
# Out:
#              sex
# sex       Female Male
# species
# Adelie        73   73
# Chinstrap     34   34
# Gentoo        58   61

# %%
# unstacking after doing groupby will allow us to group only one thing, instead of the two
hola2.plot(kind="bar");
plt.show()

# %%
# Another way of doing it
save = penguins.groupby(["species", "sex"])["sex"].count().unstack().plot(kind="bar")
plt.show()

# %% [markdown]
# Lo invertimos, o lo ponemos horizontalmente:

# %%
save = penguins.groupby(["species", "sex"])["sex"].count().unstack().plot(kind="barh" )
plt.show()

# %% [markdown]
# `promedio de las tres longitudes por especie❓`

# %%
penguins.sample(5)
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 265  Gentoo  Biscoe            43.6           13.9              217.0
# 282  Gentoo  Biscoe            45.7           13.9              214.0
# 33   Adelie   Dream            40.9           18.9              184.0
# 271  Gentoo  Biscoe            48.5           14.1              220.0
# 54   Adelie  Biscoe            34.5           18.1              187.0
#
#      body_mass_g     sex
# 265       4900.0  Female
# 282       4400.0  Female
# 33        3900.0    Male
# 271       5300.0    Male
# 54        2900.0  Female

# %% [markdown]
# Te dejo un recordatorio del .agg con su [documentación](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.agg.html)

# %%
# Group the penguins dataframe by the "species" column and calculate the mean values for three numerical features: bill_length_mm, bill_depth_mm, and flipper_length_mm.
# The result is a new dataframe called "flaps" with the mean values for each feature for each species.
flaps = penguins.groupby(["species"]).agg(
    {"bill_length_mm": "mean",
     "bill_depth_mm": "mean", 
     "flipper_length_mm": "mean" })

# Create a bar chart to visualize the mean values for each feature by species.
# Use the "kind" parameter to specify that we want a bar chart.
# Rotate the x-axis labels slightly for better readability.
flaps.plot(kind="bar")
plt.xticks(rotation=0.5)

# Add axis labels and titles for clarity.
plt.xlabel("Penguin Species", fontsize=15)
plt.ylabel("Mean Value", fontsize=15)
plt.title("Mean Values of Penguin Features by Species", fontsize=20)

# Show the plot.
plt.show()

# %% [markdown]
# ### Gráfico de Líneas
#
# Un gráfico de líneas es una herramienta de visualización popular utilizada para mostrar puntos de datos a lo largo de un intervalo continuo o período de tiempo. Es particularmente útil para mostrar tendencias, patrones y variaciones en los datos. Los gráficos de líneas se usan comúnmente en análisis y visualización de datos para representar datos con un aspecto temporal, como precios de acciones, cambios de temperatura o cifras de ventas a lo largo del tiempo.
#
# **Características Clave de los Gráficos de Líneas:**
#
# - **Eje X**: Típicamente representa la variable independiente, como el tiempo, fechas o valores numéricos que tienen un orden continuo.
#
# - **Eje Y**: Representa la variable dependiente, que puede ser cualquier valor numérico o cantidad que desees visualizar. Puede ser continuo o discreto.
#
# - **Puntos de Datos**: Los puntos de datos se trazan como puntos o marcadores en valores específicos a lo largo de los ejes X e Y. Estos puntos están conectados por líneas, que crean la característica "línea" en el gráfico.
#
# - **Líneas**: Las líneas que conectan puntos de datos ayudan a visualizar las tendencias y patrones en los datos. Facilitan la identificación de si los valores están aumentando, disminuyendo o manteniéndose relativamente constantes a lo largo del tiempo o en diferentes categorías.
#
# - **Casos de Uso**: Los gráficos de líneas se utilizan comúnmente para datos de series de tiempo, análisis de precios de acciones, pronósticos de ventas y cualquier escenario donde desees visualizar tendencias de datos.
#
# - **Personalización**: Los gráficos de líneas pueden personalizarse con varias opciones, como colores, marcadores, etiquetas y anotaciones para mejorar la presentación y claridad del gráfico.
#
# - **Interactividad**: En bibliotecas de visualización de datos interactivas como Plotly o Bokeh, los gráficos de líneas pueden hacerse interactivos, permitiendo a los usuarios hacer zoom, desplazarse o pasar el cursor sobre puntos de datos para obtener más información.
#
# Los gráficos de líneas son una herramienta poderosa para la exploración y presentación de datos. Ayudan a los analistas y tomadores de decisiones a entender cómo cambian los datos a lo largo del tiempo o en diferentes categorías, haciéndolos una parte esencial del kit de herramientas de visualización de datos.
#
# `evolución de pasajeros totales por año❓`

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
# Create a line plot using Seaborn
# - 'flights' is the DataFrame containing the data
# - 'x="year"' specifies the x-axis variable as "year" from the DataFrame
# - 'y="passengers"' specifies the y-axis variable as "passengers" from the DataFrame
# - 'ci=None' indicates that we do not want to display confidence intervals
sns.lineplot(data=flights, x="year", y="passengers", ci=None);
plt.ylabel("Average", fontsize=15);
plt.xlabel("The years", fontsize=15);
plt.title("This is the average of passengers throughout the years", fontsize = 20);
# Out:
# C:\Users\TONAC\AppData\Local\Temp\ipykernel_6748\3241608110.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=flights, x="year", y="passengers", ci=None);

# %%
# Create a line plot using Seaborn
# - 'flights' is the DataFrame containing the data
# - 'x="year"' specifies the x-axis variable as "year" from the DataFrame
# - 'y="passengers"' specifies the y-axis variable as "passengers" from the DataFrame
sns.lineplot(data=flights, x="year", y="passengers"); 
plt.ylabel("Average", fontsize=15);
plt.xlabel("The years", fontsize=15);
plt.title("This is the average of passengers throughout the years", fontsize = 20);

# %%
# Create a line plot using Seaborn
# - 'flights' is the DataFrame containing the data
# - 'x="year"' specifies the x-axis variable as "year" from the DataFrame
# - 'y="passengers"' specifies the y-axis variable as "passengers" from the DataFrame
# - 'ci=None' indicates that we do not want to display confidence intervals
# - 'estimator=sum' specifies that the estimator for the y-values should be the sum of passengers. 
#    By default, when you create a line plot using Seaborn's lineplot function without specifying 
#    the estimator parameter, the estimator used is mean.
sns.lineplot(data=flights, x="year", y="passengers", ci=None, estimator=sum); 
plt.ylabel("Total", fontsize=15);
plt.xlabel("The years", fontsize=15);
plt.title("This is the total of passengers throughout the years", fontsize = 20);
# Out:
# C:\Users\TONAC\AppData\Local\Temp\ipykernel_6748\1635461711.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=flights, x="year", y="passengers", ci=None, estimator=sum);

# %% [markdown]
# `evolución del total de pasajeros por año desglosado por mes❓`

# %%
# Create a line plot using seaborn to visualize passenger data over the years.
# The "data" parameter specifies the dataset to be used, which is the "flights" dataframe.
# The "x" parameter specifies the data for the x-axis, which is the "year" column in the dataset.
# The "y" parameter specifies the data for the y-axis, which is the "passengers" column in the dataset.

# The "hue" parameter is used to add color differentiation to the lines based on the "month" column.
# This means that each month will have a different colored line in the plot.

sns.lineplot(data=flights, x="year", y="passengers", hue="month")

# Add axis labels and a title for clarity.
plt.xlabel("Year", fontsize=15)
plt.ylabel("Number of Passengers", fontsize=15)
plt.title("Passenger Trends Over the Years by Month", fontsize=20)

# Show the legend to indicate which color corresponds to each month.
plt.legend(title="Month")

# Show the plot.
plt.show()

# %% [markdown]
# ### Diagrama de Dispersión
# Un diagrama de dispersión es una técnica fundamental de visualización de datos utilizada para explorar la relación entre dos variables continuas. Es particularmente útil para identificar patrones, tendencias, agrupaciones o valores atípicos dentro de los puntos de datos.
#
# En un diagrama de dispersión, cada punto de dato se representa como un punto en un plano bidimensional, con una variable en el eje x y otra en el eje y. Al examinar la distribución de estos puntos, puedes obtener información sobre la correlación, asociación o dispersión de las variables.
#
# Los diagramas de dispersión son valiosos para tareas como identificar relaciones lineales o no lineales, evaluar la fuerza y dirección de las correlaciones y detectar anomalías en los datos.
#
# En esta sección, exploraremos cómo crear y personalizar diagramas de dispersión utilizando las bibliotecas de visualización de datos de Python, como Matplotlib y Seaborn, para analizar visualmente las relaciones de datos y descubrir información valiosa.
#
# `¿cómo se relacionan estas dos variables cuantitativas (masa corporal y longitud de la aleta)❓`
#
# Un diagrama de dispersión utiliza puntos para representar los valores de dos variables numéricas diferentes. La posición de cada punto en los ejes horizontal y vertical indica los valores de un punto de dato individual. Los diagramas de dispersión se utilizan para observar las relaciones entre variables.

# %%
# We're using Seaborn's scatterplot function to create a scatter plot.
# The 'x' parameter specifies the variable to be plotted on the x-axis, which is 'body_mass_g' (body mass in grams).
# The 'y' parameter specifies the variable to be plotted on the y-axis, which is 'flipper_length_mm' (flipper length in millimeters).
# The 'data' parameter specifies the DataFrame we're using, which is 'penguins'.
sns.scatterplot(x="body_mass_g", y="flipper_length_mm", data=penguins)

# This code will create a scatter plot showing the relationship between body mass and flipper length of penguins.
# Each point on the plot represents a penguin, with its body mass on the x-axis and flipper length on the y-axis.
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
# Cargar el dataset de penguins que incluye las variables body_mass_g y flipper_length_mm
penguins = sns.load_dataset("penguins")

# Crear el scatter plot con una línea de tendencia
sns.regplot(x="body_mass_g", y="flipper_length_mm", data=penguins)

# Mostrar el gráfico
plt.title('Relación entre Body Mass y Flipper Length en Pingüinos')
plt.show()

# %% [markdown]
# `¿cómo se relacionan estas variables cuantitativas (masa corporal y longitud de la aleta) con esta categórica (especies)❓`

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# We're using Seaborn's scatterplot function to create a scatter plot.
# The 'x' parameter specifies the variable to be plotted on the x-axis, which is 'body_mass_g' (body mass in grams).
# The 'y' parameter specifies the variable to be plotted on the y-axis, which is 'flipper_length_mm' (flipper length in millimeters).
# The 'hue' parameter adds color differentiation to the points based on the 'species' variable.
# The 'data' parameter specifies the DataFrame we're using, which is 'penguins'.
# The 'size' parameter specifies the variable that determines the size of the points, which is 'bill_length_mm' (bill length in millimeters).
# The 'sizes' parameter sets the range of sizes for the points from 0 to 300.
# The 'style' parameter adds different point styles for data points based on the 'island' variable.

sns.scatterplot(x="body_mass_g", y="flipper_length_mm", hue="species", data=penguins, size='bill_length_mm',
                sizes=(0, 300), style="island")

# This code will create a scatter plot showing the relationship between body mass and flipper length of penguins.
# Points will be colored based on the penguin species, sized based on bill length, and styled based on the island.
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %% [markdown]
# Podemos hacer que el tamaño de los puntos dependa de una variable numérica

# %%
# Creating a scatter plot using Seaborn's scatterplot function.
# The 'x' parameter specifies the variable for the x-axis, which is 'body_mass_g' (body mass in grams).
# The 'y' parameter specifies the variable for the y-axis, which is 'flipper_length_mm' (flipper length in millimeters).
# The 'hue' parameter adds color differentiation based on the 'species' variable.
# The 'size' parameter sets the size of points based on the 'flipper_length_mm' variable.

sns.scatterplot(x="body_mass_g", y="flipper_length_mm", hue="species", data=penguins, size="flipper_length_mm")

# This code creates a scatter plot with points colored by species and sized based on flipper length.
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
# Creating a scatter plot with Seaborn's scatterplot function.
# The 'x' parameter specifies the variable for the x-axis, which is 'body_mass_g' (body mass in grams).
# The 'y' parameter specifies the variable for the y-axis, which is 'flipper_length_mm' (flipper length in millimeters).
# The 'hue' parameter adds color differentiation based on the 'species' variable.
# The 'size' parameter sets the size of points based on the 'bill_length_mm' variable.

sns.scatterplot(x="body_mass_g", y="flipper_length_mm", hue="species", data=penguins, size="bill_length_mm")

# This code generates a scatter plot with points colored by species and sized based on bill length.
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
# Creating a scatter plot using Seaborn's scatterplot function.
# The 'x' parameter specifies the variable for the x-axis, which is 'body_mass_g' (body mass in grams).
# The 'y' parameter specifies the variable for the y-axis, which is 'flipper_length_mm' (flipper length in millimeters).
# The 'hue' parameter adds color differentiation based on the 'species' variable.
# The 'size' parameter sets the size of points based on the 'bill_length_mm' variable.
# The 'style' parameter adds different point styles based on the 'island' variable.

sns.scatterplot(x="body_mass_g", y="flipper_length_mm", hue="species", data=penguins, size="bill_length_mm", style="island")

# This code creates a scatter plot with points colored by species, sized based on bill length, and styled based on island.
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %% [markdown]
# #### matplotlib: scatterplot

# %% [markdown]
# `¿cómo se relacionan estas dos variables cuantitativas (masa corporal y longitud de la aleta)❓`

# %%
# Creating a scatter plot using Matplotlib's plt.scatter() function.
# The 'x' parameter specifies the variable for the x-axis, which is 'body_mass_g' (body mass in grams).
# The 'y' parameter specifies the variable for the y-axis, which is 'flipper_length_mm' (flipper length in millimeters).

plt.scatter(x=penguins["body_mass_g"], y=penguins["flipper_length_mm"])

# Adding labels to the x-axis and y-axis for better understanding.
plt.xlabel("Chunkiness", fontsize=15)
plt.ylabel("Flipper Length", fontsize=15)

# Setting a title for the scatter plot.
plt.title("Body Mass vs. Flipper Length", fontsize=20)

# This code creates a basic scatter plot using Matplotlib, representing the relationship between body mass and flipper length.
# Out:
# Text(0.5, 1.0, 'Body Mass vs. Flipper Length')

# %% [markdown]
# ## DISTRIBUCIÓN
#
# En la visualización de datos, entender la distribución de tus datos es esencial. Te ayuda a obtener información sobre cómo se dispersan tus datos y si siguen un patrón particular. Las siguientes técnicas se utilizan comúnmente para explorar la distribución de datos:
#
# - **Histogramas:** Los histogramas proporcionan una representación visual de la frecuencia o conteo de puntos de datos dentro de intervalos o bins específicos. Son útiles para comprender la forma y tendencias centrales de datos numéricos.
#
# - **Boxplots:** Los boxplots, también conocidos como diagramas de caja y bigotes, muestran la distribución de datos a través de cuartiles. Ayudan a identificar valores atípicos y proporcionan un resumen conciso de la dispersión de los datos.
#
# - **Estimación de Densidad Kernel (KDE):** KDE es una técnica para estimar la función de densidad de probabilidad de una variable aleatoria continua. Ayuda a visualizar la distribución suave de puntos de datos y es particularmente útil para comprender la distribución subyacente de los datos.
#
# Cada uno de estos métodos tiene sus fortalezas y es adecuado para diferentes tipos de exploración de datos. Elige el que mejor se ajuste a tus necesidades analíticas al examinar la distribución de tus datos.
#
# ### Histogramas
#
# Los histogramas son representaciones gráficas que se asemejan a los gráficos de barras verticales. Sin embargo, sirven a un propósito distinto en la visualización de datos. Los histogramas son particularmente útiles para comprender la distribución de frecuencia subyacente de un conjunto de datos, ya sea que consista en valores discretos o continuos medidos en una escala de intervalo.
#
# Características clave y beneficios de los histogramas incluyen:
#
# - **Distribución de Frecuencia:** Los histogramas proporcionan información sobre la distribución de puntos de datos dentro de intervalos o bins especificados. Al visualizar cómo se distribuyen los datos a través de estos bins, puedes observar patrones y tendencias.
#
# - **Asimetría y Curtosis:** Los histogramas te permiten evaluar propiedades como la asimetría (si los datos están sesgados hacia la izquierda o derecha) y la curtosis (que mide la concentración de valores alrededor de la región central de la distribución). Estas propiedades ofrecen información valiosa sobre la forma y características del conjunto de datos.
#
# - **Representación de Intervalos:** La elección de intervalos o bins en un histograma puede impactar la interpretación de los datos. Ajustar los tamaños de los bins puede revelar diferentes aspectos de la distribución.
#
# Los histogramas son una herramienta fundamental en el análisis exploratorio de datos (EDA) y a menudo son el primer paso para evaluar la naturaleza de tus datos. Proporcionan una base visual para comprender las distribuciones de datos, lo que puede informar análisis y decisiones subsecuentes.
#
# ![asimetría](https://d2mk45aasx86xg.cloudfront.net/image1_11zon_4542aedc45.webp)
#
# #### seaborn: histogramas
#
# `¿cómo se distribuye la edad❓`

# %%
titanic_2.fillna(old_mean, inplace=False).Age.mean() #before dropping values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 titanic_2.fillna(old_mean, inplace=False).Age.mean()
#
# NameError: name 'titanic_2' is not defined

# %%
# Create a histogram of passenger ages from the Titanic dataset
sns.histplot(x=titanic.Age);

# %%
# Create a histogram with more bins to show finer detail of passenger ages
sns.histplot(x=titanic.Age, bins=50);  # Do we want this much detail?

# %%
# Fill missing values in the 'Age' column with the mean age of passengers
titanic.Age.fillna(titanic.Age.mean(), inplace=True)

# Create a histogram of passenger ages after filling missing values with the mean age
sns.histplot(x=titanic.Age);
# Out:
# C:\Users\TONAC\AppData\Local\Temp\ipykernel_6748\3000334048.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic.Age.fillna(titanic.Age.mean(), inplace=True)

# %% [markdown]
# Hemos manipulado los datos rellenando los NaN con 0 y hemos cambiado la distribución de los datos. Podemos especificar manualmente el número de `boxes`.

# %%
sns.histplot(x=titanic.Age, bins=30)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# Podemos elegir si lo rellenamos o no...

# %%
sns.histplot(x=titanic.Age, bins=40, fill=None);

# %%
# Create a histogram of passenger ages with 30 bins, no fill, and a kernel density estimate (KDE) overlay
sns.histplot(x=titanic.Age, bins=30, fill=None, kde=True);

# The 'kde' parameter adds a kernel density estimate (probability density function) to the histogram

# %% [markdown]
# ### Estimación de Densidad Kernel (KDE) en Histogramas
#
# En el contexto de los histogramas, el parámetro 'kde', abreviatura de Kernel Density Estimate (Estimación de Densidad Kernel), es una técnica estadística utilizada para estimar la función de densidad de probabilidad (PDF) de una variable aleatoria continua. Cuando 'kde' se establece en True en la función `sns.histplot`, añade una curva suave sobre las barras del histograma.
#
# Esta curva representa la distribución de probabilidad estimada de los puntos de datos. Proporciona una representación más continua y suavizada de la distribución subyacente de los datos, facilitando la visualización de la forma y características de los datos.
#
# En términos más simples, la curva KDE nos ayuda a entender cuán probables son los diferentes valores en el conjunto de datos. Los picos en la curva KDE indican dónde los datos están más concentrados, mientras que los valles indican regiones de menor concentración. Es una herramienta útil para comprender el patrón general y la densidad de los puntos de datos en un histograma.
#
# Podemos pedir una aproximación de la distribución / estimación de densidad kernel.

# %%
sns.histplot(x=titanic.Age, bins=12, kde=True);

# %% [markdown]
# #### matplotlib: histograms

# %% [markdown]
# `como está distribuida la edad❓`

# %% [markdown]
# https://htmlcolorcodes.com

# %%
# Plotting a histogram of the 'Age' column from the Titanic dataset
# - bins=10: Divides the range of ages into 10 equal-width bins.
# - rwidth=0.90: Reduces the width of each bar in the histogram to 90% of the bin width.
# - color="#fdea14": Sets the color of the bars to a bright yellow.
titanic.Age.plot.hist(bins=10, rwidth=0.90, color="#fdea14")
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Plotting another histogram of the 'Age' column
# - bins=30: Divides the range of ages into 30 equal-width bins, providing more detail.
# - color="#21211d": Sets the color of the bars to a dark gray.
# - rwidth=0.90: Reduces the width of each bar to 90% of the bin width.
# - histtype="step": Displays the histogram as a step plot, showing only the outline.
titanic.Age.plot.hist(bins=30, color="#21211d", rwidth=0.90, histtype="step")
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### Con variables categoricas

# %% [markdown]
# `¿cómo se distribuye la masa corporal a través de las especies❓`

# %%
# Visualizing how body mass is distributed across penguin species
# - data=penguins: Specifies the dataset to use, which is 'penguins' in this case.
# - x="species": Sets the 'species' column as the x-axis (categorical variable).
# - y="body_mass_g": Sets the 'body_mass_g' column as the y-axis.
sns.scatterplot(data=penguins, x="species", y="body_mass_g")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# La representación predeterminada de datos en catplot() utiliza un diagrama de dispersión. Hay dos tipos diferentes de diagramas de dispersión categóricos en seaborn, cada uno abordando el desafío de representar datos categóricos con un diagrama de dispersión. Estos gráficos ayudan a visualizar cómo se distribuyen los puntos de datos dentro de cada categoría a lo largo del eje de la variable categórica.

# %%
# Creating a categorical plot to visualize how body mass is distributed across penguin species.
# - data=penguins: Specifies the dataset to use, which is 'penguins' in this case.
# - x="species": Sets the 'species' column as the x-axis (categorical variable).
# - y="body_mass_g": Sets the 'body_mass_g' column as the y-axis.
sns.catplot(data=penguins, x="species", y="body_mass_g")

# %%
# Creating a categorical plot with hue and jitter.
# - data=penguins: Specifies the dataset to use, which is 'penguins' in this case.
# - x="species": Sets the 'species' column as the x-axis (categorical variable).
# - y="body_mass_g": Sets the 'body_mass_g' column as the y-axis.
# - hue="sex": Adds color differentiation based on the 'sex' column.
# - jitter=True: Adds jitter to data points to prevent overlapping.
sns.catplot(data=penguins, x="species", y="body_mass_g", hue="sex", jitter=True)

# %%
# Creating a categorical plot with hue and alpha transparency.
# - data=penguins: Specifies the dataset to use, which is 'penguins' in this case.
# - x="species": Sets the 'species' column as the x-axis (categorical variable).
# - y="body_mass_g": Sets the 'body_mass_g' column as the y-axis.
# - hue="sex": Adds color differentiation based on the 'sex' column.
# - alpha=0.3: Adjusts the transparency of data points (0.0 for fully transparent, 1.0 for fully opaque).
sns.catplot(data=penguins, x="species", y="body_mass_g", hue="sex", alpha=0.3)

# %% [markdown]
# ### swarmplot
#
# Un swarmplot es un tipo de gráfico de dispersión categórico que tiene como objetivo mostrar la distribución de puntos de datos para diferentes categorías mientras se evita la superposición de puntos. Es particularmente útil cuando tienes datos discretos o categóricos y quieres visualizar puntos de datos individuales.
#
# En un swarmplot:
# - Cada punto de dato se representa como un punto a lo largo del eje categórico.
# - Los puntos se ajustan para evitar la superposición, proporcionando una vista clara de la distribución de datos.
# - Los swarmplots son excelentes para visualizar la dispersión y densidad de datos dentro de las categorías.
#
# Los swarmplots son herramientas valiosas para el análisis exploratorio de datos cuando se trata con datos categóricos o discretos, ya que proporcionan información sobre la distribución de puntos de datos individuales dentro de cada categoría.
#
# `¿cómo se distribuye la masa corporal a través de las especies y entre macho/hembra❓`

# %%
# Create a swarmplot to visualize the distribution of body_mass_g across different sexes for each penguin species.
sns.swarmplot(data=penguins, x="body_mass_g", y="sex", hue="species")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='sex'>

# %%
# Create another swarmplot, this time showing the distribution of body_mass_g for each penguin species with distinction by sex.
# The 'alpha' parameter controls the transparency of the points.
sns.swarmplot(data=penguins, x="body_mass_g", y="species", hue="sex", alpha=0.9)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='species'>

# %% [markdown]
# ### Boxplot
#
# Un boxplot, también conocido como diagrama de caja y bigotes, es una herramienta valiosa para visualizar la distribución de un conjunto de datos e identificar medidas estadísticas clave. Proporciona un resumen conciso de la tendencia central de los datos, la dispersión y la presencia de valores atípicos.
#
# Componentes clave de un boxplot:
# - **Mediana (Q2)**: La línea dentro de la caja representa la mediana, que es el valor medio del conjunto de datos cuando se ordena en orden ascendente. Divide los datos en dos mitades iguales, con el 50% de los valores por debajo y el 50% por encima de ella.
#
# - **Rango Intercuartil (IQR)**: La caja encierra el IQR, que es el rango entre el primer cuartil (Q1) y el tercer cuartil (Q3). El IQR abarca el 50% central de los datos y proporciona una medida de la dispersión de los datos.
#
# - **Bigotes**: Los bigotes se extienden desde los bordes de la caja hasta los valores mínimos y máximos dentro de un rango definido. Los valores atípicos, si están presentes, se muestran como puntos individuales más allá de los bigotes.
#
# - **Valores Atípicos**: Los valores atípicos son puntos de datos que caen significativamente fuera de los bigotes. Típicamente se muestran como puntos individuales y pueden indicar valores inusuales o extremos en el conjunto de datos.
#
# Los boxplots son valiosos para comparar distribuciones, identificar asimetría y detectar posibles valores atípicos en los datos. Proporcionan un resumen visual de las propiedades estadísticas de los datos, facilitando la comprensión de características esenciales de un conjunto de datos.
#
# Para crear un boxplot en Python, puedes usar bibliotecas como Matplotlib o Seaborn, especificando la variable que deseas visualizar. Los boxplots son una herramienta poderosa para el análisis exploratorio de datos y para obtener insights sobre la distribución de tus datos.
#
# ![boxplots](https://www.simplypsychology.org/box-whisker-plot.jpg)
#
# `¿cómo se distribuye la edad❓(titanic)`

# %%
sns.boxplot(x="Age", data=titanic);

# %% [markdown]
# `how is the age distributed across classes❓ (titanic)`

# %%
sns.boxplot(x="Pclass", y="Age", data=titanic);

# %% [markdown]
# ### ViolinPlot
#
# Un Violin Plot es una técnica de visualización de datos versátil que combina elementos de un box plot con un gráfico de densidad de kernel rotado. Es particularmente útil para visualizar la distribución y densidad de probabilidad de un conjunto de datos a través de diferentes categorías o variables.
#
# Características clave de un Violin Plot:
# - **Forma Simétrica**: El núcleo de un Violin Plot se asemeja a una forma simétrica de violín rotado. Esta forma representa la densidad de probabilidad estimada de los datos en diferentes valores a lo largo del eje y.
#
# - **Box Plot Interior**: Similar a un box plot, una caja central se dibuja dentro de la forma de violín. Esta caja denota el rango intercuartil (IQR) y la mediana de los datos. El ancho de la caja es proporcional a la densidad de puntos de datos en ese valor.
#
# - **Extended Tails**: Las colas del violin plot se extienden hacia afuera, indicando el rango de valores de datos. El ancho de las colas corresponde a la densidad de puntos de datos en diferentes valores.
#
# Los Violin Plots son beneficiosos para comparar la distribución de datos a través de múltiples categorías o grupos, especialmente cuando se trata de conjuntos de datos complejos. Proporcionan información sobre la tendencia central de los datos, la dispersión y la presencia de múltiples modos o picos dentro de la distribución.
#
# Al visualizar tanto el box plot como la estimación de densidad de kernel, los Violin Plots ofrecen una vista comprensiva de las propiedades estadísticas de los datos. Esto los convierte en una herramienta valiosa en el análisis exploratorio de datos y la visualización de datos.
#
# Puedes crear Violin Plots en Python usando bibliotecas como Seaborn o Matplotlib, especificando las variables que deseas comparar o visualizar.
#
# `¿cómo se distribuye la edad❓`

# %%
# Create a violin plot for the 'Age' column in the Titanic dataset
violin = sns.violinplot(x=titanic.Age)

# Add a vertical line at the median age
violin.axvline(x=titanic.Age.median(), c="red", label="median")

# Add a legend to the plot to label the red line as 'median'
plt.legend();

# %% [markdown]
# `¿cómo se distribuye la longitud del pico a través de las especies❓`

# %%
# Create a violin plot for the 'bill_length_mm' column in the Penguins dataset, grouped by 'species'
sns.violinplot(x=penguins.bill_length_mm, y=penguins.species)
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='species'>

# %% [markdown]
# ### Gráfico KDE
# Esta función permite mucho más control sobre el gráfico resultante que la función seaborn.distplot. Si pasamos como primer argumento el conjunto de valores de y calculados en la sección anterior, obtenemos exactamente el mismo gráfico.
#
# [Seaborn: kdeplot](https://seaborn.pydata.org/generated/seaborn.kdeplot.html)
#
# `¿cómo se distribuye la edad❓`

# %%
sns.kdeplot(x=titanic.Age);

# %% [markdown]
# #### Con más variables
#
# `¿cómo se distribuye la edad a través de las clases❓`

# %%
sns.kdeplot(x=titanic.Age, hue=titanic.Pclass);

# %%
sns.kdeplot(x=titanic.Age, hue=titanic.Pclass, fill=True);

# %% [markdown]
# #### Añadir KDE al histplot
# Las líneas que vamos a añadir son de la biblioteca matplotlib, pero... lo bueno es que podemos combinar ambas bibliotecas

# %%
# Create a histogram plot for the 'Age' column in the Titanic dataset with a KDE overlay and save it as a variable 'graf'
graf = sns.histplot(x=titanic.Age, kde=True)

# Add vertical lines to the plot at specific x-values
graf.axvline(x=titanic.Age.mean(), c="red", label="mean")     # Red vertical line at the mean age
graf.axvline(x=titanic.Age.median(), c="green", label="median") # Green vertical line at the median age
graf.axvline(x=titanic.Age.max(), c="blue", label="max")       # Blue vertical line at the maximum age

# Add a horizontal line to the plot at y=60
graf.axhline(y=60, c="black", label="Horizontal")              # Black horizontal line at y=60

# Display a legend to label the lines on the plot
plt.legend()

# %% [markdown]
# ## PARTE DE UN TODO
#
# En esta sección, exploramos técnicas de visualización que nos ayudan a entender cómo las partes individuales contribuyen a un todo. Estas visualizaciones son particularmente útiles cuando queremos analizar la composición de un conjunto de datos o entender la distribución de categorías dentro de un contexto más amplio.
#
# Cubriremos los siguientes tipos de visualización:
#
# - Gráfico circular
# - Gráfico de barras apiladas
# - Gráfico de columnas apiladas
#
# ### Gráfico circular 👀
#
# - ⚠️ Los gráficos circulares son visualmente intuitivos, pero pueden no ser la mejor opción para mostrar datos cuantitativos de manera efectiva.
# - ⚠️ Las porciones pequeñas, como aquellas que representan un pequeño porcentaje del total, corren el riesgo de ser demasiado diminutas para discernir en el gráfico.
# - ⚠️ Comparar áreas y ángulos en un gráfico circular, especialmente cuando representan valores similares, puede ser desafiante para los espectadores.
#
# Los gráficos circulares son más adecuados para mostrar la distribución proporcional de categorías distintas dentro de un conjunto de datos. Sin embargo, es esencial usarlos con juicio, considerando sus limitaciones al presentar datos.
#
# `¿cuál es la proporción de especies❓`

# %%
# Creating a pie chart from the 'penguins' DataFrame
# The 'autopct' parameter specifies the format for displaying the percentage on each pie slice
penguins.groupby("species")['species'].count().plot.pie(autopct="%.1f%%")
# Out:
# <Axes: ylabel='species'>

# %% [markdown]
# ### Gráfico de columnas apiladas
#
# En la visualización de datos, un gráfico de columnas apiladas es un tipo de gráfico que representa los datos en formato de columna, donde múltiples columnas se apilan una encima de la otra para mostrar la composición de un todo mientras se preservan las contribuciones individuales de cada componente. Los gráficos de columnas apiladas son particularmente útiles para mostrar datos categóricos donde quieres enfatizar el total al mismo tiempo que resaltas la distribución de categorías dentro de ese total.
#
# #### seaborn: columna apilada (histograma)

# %% [markdown]
# `how is the age of people that survived/didnt survive distributed❓`

# %%
sns.histplot(data=titanic, x="Age", hue="Survived", multiple="stack");

# %%
# 1. Create figure
sns.histplot(x=titanic.Age, hue=titanic.Survived, multiple="stack")

# 2. Modify figure
plt.axvline(x=65)  # Vertical line at age 65
plt.axhline(y=60)  # Horizontal line at 60
plt.axhline(y=80, c="red")  # Red horizontal line at 80

# 2.1. Detail
plt.title("Distribution of Age and Survival", size=20)  # Set the title
plt.xlabel("YOUNG -> OLD")  # Set the x-axis label
plt.ylabel("THIS IS HOW MANY")  # Set the y-axis label

# 3. Save figure
# --> plt.savefig("..age_and_death")  # Save the figure to a file
plt.show()  # Display the figure

# %%
# Create a stacked histogram of Age distribution based on Pclass
sns.histplot(data=titanic, x="Age", hue="Pclass", multiple="stack")

# Add vertical lines at the mean, 25th percentile, and 75th percentile of Age
plt.axvline(titanic.Age.mean(), color="red", linestyle="--", label="Mean Age")
plt.axvline(titanic.Age.quantile(0.75), color="green", linestyle="--", label="75th Percentile")
plt.axvline(titanic.Age.quantile(0.25), color="blue", linestyle="--", label="25th Percentile")

# Add labels and a legend
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Age Distribution by Pclass")
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# Documentación de histogramas --> https://seaborn.pydata.org/generated/seaborn.histplot.html
#
# `¿cómo puedo comparar tres distribuciones compuestas diferentes a la vez❓`

# %%
# Create subplots with 1 row and 3 columns, and set the figure size
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(20, 5))

# 1. Regular Histogram
sns.histplot(data=penguins, x="flipper_length_mm", hue="species", ax=axs[0])
axs[0].set_title("Regular Histogram")

# 2. Histogram for flipper lengths above 170
sns.histplot(data=penguins[penguins.flipper_length_mm > 170], x="flipper_length_mm", hue="species", multiple="stack", palette="mako", ax=axs[1])
axs[1].set_title("Histogram for Flipper Lengths Above 170")

# 3. Histogram for all flipper lengths with two species
sns.histplot(data=penguins, x="flipper_length_mm", hue="species", palette="mako", ax=axs[2])
axs[2].set_title("Histogram for All Flipper Lengths (Two Species)")

# Show the plots
plt.show()

# %% [markdown]
# ### Correlation matrix
#
# La matriz de correlación es una métrica de análisis de datos esencial utilizada para resumir los datos y entender las relaciones entre diversas variables. Ayuda en la toma de decisiones informadas basadas en las interdependencias entre estas variables.
#
# En una matriz de correlación:
#
# - Los valores cercanos a 1 indican una fuerte correlación positiva.
# - Los valores cercanos a -1 indican una fuerte correlación negativa.
# - Los valores cercanos a 0 indican una correlación débil o nula.
#
# `¿en qué medida están relacionadas estas variables cuantitativas❓`

# %%
titanic['Sex'] = titanic['Sex'].map(dict(zip(['male','female'],[0,1])))

# Calculate the correlation matrix for the Titanic dataset
numeric_columns = titanic.select_dtypes(include=['float64', 'int64'])

# Calcular la matriz de correlación
corr = numeric_columns.corr()

display(corr)
# Out:
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000 -0.005007 -0.035144 -0.042939  0.033207 -0.057527
# Survived       -0.005007  1.000000 -0.338481  0.543351 -0.069809 -0.035322
# Pclass         -0.035144 -0.338481  1.000000 -0.131900 -0.331339  0.083081
# Sex            -0.042939  0.543351 -0.131900  1.000000 -0.084153  0.114631
# Age             0.033207 -0.069809 -0.331339 -0.084153  1.000000 -0.232625
# SibSp          -0.057527 -0.035322  0.083081  0.114631 -0.232625  1.000000
# Parch          -0.001652  0.081629  0.018443  0.245489 -0.179191  0.414838
# Fare            0.012658  0.257307 -0.549500  0.182333  0.091566  0.159651
#
#                 Parch      Fare
# PassengerId -0.001652  0.012658
# Survived     0.081629  0.257307
# Pclass       0.018443 -0.549500
# Sex          0.245489  0.182333
# Age         -0.179191  0.091566
# SibSp        0.414838  0.159651
# Parch        1.000000  0.216225
# ...

# %%
pip install --upgrade seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
sns.__version__
# Out:
# '0.13.2'

# %%
# Create a heatmap to visualize the correlation matrix
sns.heatmap(corr, annot=True);

# %% [markdown]
# ## Entendiendo las Funciones de NumPy en la Creación de Heatmaps
#
# En el contexto de la creación de heatmaps, NumPy, una poderosa biblioteca de cómputo numérico en Python, ofrece herramientas valiosas para manipular datos antes de visualizarlos. Dos funciones esenciales de NumPy comúnmente utilizadas en la generación de heatmaps son `np.triu` y `np.ones_like`.
#
# - [**Documentación de `np.triu`**](https://numpy.org/doc/stable/reference/generated/numpy.triu.html): Esta función, abreviatura de "triangular upper" (parte triangular superior), se utiliza para crear una máscara booleana que retiene solo la parte superior triangular de una matriz mientras establece la parte inferior en `False`. Es particularmente útil al visualizar matrices de correlación o datos simétricos similares.
#
# - [**Documentación de `np.ones_like`**](https://numpy.org/doc/stable/reference/generated/numpy.ones_like.html): Esta función genera un arreglo de unos con la misma forma y tipo de datos que un arreglo de entrada especificado. A menudo se emplea para crear una matriz inicial con valores `True` o `1` antes de aplicar una máscara.
#
# En el contexto de la creación de heatmaps, estas funciones de NumPy juegan un papel crucial en mejorar la visualización de matrices de correlación. Al usar `np.triu` en combinación con `np.ones_like`, podemos enfocarnos en visualizar solo una mitad de la matriz de correlación, típicamente la porción triangular superior. Esto evita información redundante y resulta en un heatmap más conciso e interpretable, especialmente cuando se trata con datos simétricos como los coeficientes de correlación.
#
# Al entender cómo usar estas funciones de NumPy en la creación de heatmaps, puedes adaptar efectivamente tus visualizaciones para resaltar las relaciones esenciales dentro de tus datos, facilitando la extracción de insights y conclusiones significativas.

# %%
sns.__version__

# %%
# Creating a boolean mask for the upper triangular part of the correlation matrix
mask = np.triu(np.ones_like(corr, dtype=bool))

# Creating a color map for the heatmap using seaborn's diverging_palette
color_map = sns.diverging_palette(0, 10, as_cmap=True)

# Creating a heatmap using seaborn
sns.heatmap(corr,  
            mask=mask,               # Applying the upper triangular mask to hide redundant information
            cmap=color_map,          # Setting the color map for the heatmap
            square=True,             # Making the heatmap square
            linewidth=0.5,           # Setting the linewidth between cells
            vmax=1,                  # Defining the maximum color scale value
            vmin=-1,                 # Defining the minimum color scale value
            cbar_kws={"shrink": .5}  # Customizing the colorbar appearance
);

# Displaying the heatmap
plt.show()

# %% [markdown]
# ### Pairplot
# Graficamos relaciones entre las variables
#
# `¿cómo se comparan todas estas variables❓`

# %%
sns.pairplot(penguins);

# %% [markdown]
# `¿cómo se comparan todas estas variables a través de las especies❓`

# %%
sns.pairplot(penguins, hue="species");

# %% [markdown]
# ## TENDENCIAS
#
# ### Gráfico de Líneas
#
# `¿cómo cambian todos estos grupos a lo largo del tiempo❓`

# %%
df = pd.DataFrame({'years': [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
                   'Data': [20, 12, 15, 14, 19, 23, 25, 29],
                   'UX': [5, 7, 7, 9, 12, 9, 9, 4],
                   'Web dev': [1, 1, 10, 6, 6, 5, 9, 12]})

# %%
data = pd.melt(df, ['years'])
sns.lineplot(x='years', y="value", hue='variable', 
             data=data,
             palette=['red', 'blue', 'purple']);

# %% [markdown]
# ### Area chart
#
# `¿cómo cambia la población a lo largo del tiempo y cómo es diferente a través de estas ciudades❓`

# %%
df = pd.DataFrame({'years': [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
                   'Barcelona': [20000, 12000, 15000, 14000, 19000, 23000, 25000, 29000],
                   'Madrid': [5000, 7000, 7000, 9000, 12000, 9000, 9000, 4000],
                   'Valencia': [1000, 8000, 10000, 6000, 6000, 5000, 9000, 12000]})

# %%
#define colors to use in chart
color_map = ['red', 'steelblue', 'pink']
    
#create area chart
plt.stackplot(df.years, df.Barcelona, df.Madrid, df.Valencia,
              labels=['Barcelona', 'Madrid', 'Valencia'],
              colors=color_map)

#add legend
plt.legend(loc='upper left')

#add axis labels
plt.xlabel('Years')
plt.ylabel('Population')

#display area chart
plt.show()

# %% [markdown]
# ----------------------------------------------------------------

# %% [markdown]
# ### Jointplot: histograms & scatterplot
# Dibuja un gráfico de dos variables con gráficos bivariados y univariados. Es similar a un diagrama de dispersión pero añade los histogramas individuales de ambas variables.

# %%
penguins.head()

# %%
sns.jointplot(data=penguins, x= "bill_depth_mm", y= "flipper_length_mm");

# %% [markdown]
# Asignar una variable `hue` añadirá colores condicionales al diagrama de dispersión y dibujará curvas de densidad separadas (usando kdeplot()) en los ejes marginales.

# %%
sns.jointplot(data=penguins, x= "bill_depth_mm", y= "flipper_length_mm", hue="species");

# %%
sns.jointplot(data=penguins, x= "body_mass_g", y= "flipper_length_mm");

# %% [markdown]
# - ¿Puedes hacer un Jointplot con matplotlib?
# Sí, pero tienes que configurar las figuras y hacerlo de forma independiente... aquí hay un [tutorial](https://stackabuse.com/matplotlib-scatter-plot-with-distribution-plots-histograms-jointplot/)
#
# ## Subgráficos
# Se utilizan para pintar varios gráficos en la misma "imagen"

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Create a 2x3 grid of subplots with a specified figure size
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(20, 15))

# Plot 1: Horizontal bar chart showing counts of penguins by species and sex
penguins.groupby(["species", "sex"])["sex"].count().unstack().plot(kind="barh", ax=axs[0, 0])

# Plot 2: Violin plot displaying the distribution of bill lengths by penguin species
sns.violinplot(x=penguins.bill_length_mm, y=penguins.species, ax=axs[0, 1])

# Plot 3: Stack multiple histograms of flipper lengths by species for comparison
sns.histplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack", ax=axs[0, 2])

# Plot 4: Swarm plot showing body mass distribution by penguin sex and species
sns.swarmplot(data=penguins, x="body_mass_g", y="sex", hue="species", ax=axs[1, 0])

# Plot 5: Pie chart displaying the distribution of penguin species
pens.plot.pie(autopct="%.1f%%", ax=axs[1, 1])

# Plot 6: Count plot showing the distribution of penguin sex
sns.countplot(x=penguins.sex, ax=axs[1, 2])

# %% [markdown]
# ## Save Plots

# %%
scatter = sns.scatterplot(x="body_mass_g", y="flipper_length_mm", data=penguins, hue="species");
scatter.figure.savefig("../scatter.jpg", dpi=1000)

# %% [markdown]
# ## Resumen: Visualizaciones de Análisis Exploratorio de Datos (EDA)
#
# En esta sección de visualización de EDA, exploramos varios tipos de visualizaciones para obtener insights de nuestros conjuntos de datos. Estas visualizaciones nos ayudan a entender las distribuciones de datos, las relaciones entre variables y más. Repasemos las visualizaciones clave que cubrimos:
#
# ### Visualizaciones de Datos Categóricos:
#
# - **Gráficos de Barras:** Se utilizan para visualizar conteos de datos categóricos.
# - **Gráficos de Barras Agrupadas:** Muestran conteos de datos categóricos con agrupación.
# - **Gráficos de Barras Apiladas:** Muestran conteos de datos con apilamiento.
# - **Gráficos de Conteo:** Muestran el conteo de datos categóricos usando barras.
#
# ### Visualizaciones de Datos Numéricos:
#
# - **Histogramas:** Visualizan la distribución de datos numéricos.
# - **Estimación de Densidad Kernel (KDE):** Grafica la función de densidad de probabilidad sobre los histogramas.
# - **Box Plots:** Muestran cuartiles e identifican valores atípicos.
# - **Violin Plots:** Combinan box plots y KDE para visualizar la distribución de datos.
#
# ### Visualizaciones de Relaciones:
#
# - **Gráficos de Dispersión:** Muestran relaciones entre dos variables numéricas.
# - **Gráficos de Pares:** Muestran relaciones por pares entre múltiples variables.
# - **Heatmaps:** Visualizan correlaciones entre variables numéricas.
#
# ### Visualizaciones de Parte de un Todo:
#
# - **Gráficos Circulares:** Representan partes de un todo, pero pueden ser menos efectivos para datos cuantitativos.
# - **Gráficos de Barras Apiladas:** Muestran partes de un todo con barras apiladas.
# - **Gráficos de Columnas Apiladas:** Presentan partes de un todo con columnas apiladas.
#
# Estas visualizaciones nos permiten explorar nuestros conjuntos de datos, identificar patrones y obtener insights para guiar el análisis y la toma de decisiones posteriores.
#
# Recuerda elegir el tipo de visualización más apropiado basado en tus datos y los insights que deseas extraer.
